# %%
# Libraries

from pypdf import PdfReader, PdfWriter, PageObject, Transformation
import camelot
import pandas as pd
import os

# %%
# Define functions

#Define a function to extract specific pages from a PDF file

def extract_pdf(source_path, new_pdf, start_page, end_page):
    """
    Splits a PDF into a new PDF containing only the specified page range.
    Creates the output directory if it does not exist.

    Parameters:
        source_path (str): Path to the input PDF file.
        new_pdf (str): Path to save the output PDF file.
        start_page (int): Starting page number (inclusive, 1-based).
        end_page (int): Ending page number (inclusive, 1-based).
    """
    output_dir = os.path.dirname(new_pdf)
    os.makedirs(output_dir, exist_ok=True)  # Ensure the directory exists

    reader = PdfReader(source_path)
    writer = PdfWriter()

    for page_num in range(start_page - 1, end_page):
        writer.add_page(reader.pages[page_num])

    with open(new_pdf, "wb") as f:
        writer.write(f)

    print(f"Saved new PDF to {new_pdf} with pages {start_page}-{end_page}")

# Define a function to split each PDF page in half, 
# then crop odd and even pages to specific respective dimensions.
# Cropping can be delicate, so best to test dimensions by sight for each use of the function.

def split_and_crop(input_path, output_filename, odd_crop, even_crop):
    """
    Crops odd and even pages of a PDF with different dimensions and saves the result.

    Parameters:
        input_path (str): Path to the input PDF file.
        output_filename (str): Name of the output PDF file (not path).
        odd_crop (dict): Crop dimensions for odd pages.
        even_crop (dict): Crop dimensions for even pages.
    """
    # Use the same directory as the input PDF for output
    output_dir = os.path.dirname(input_path)
    os.makedirs(output_dir, exist_ok=True)  # Ensure the directory exists
    output_path = f"{output_dir}\\{output_filename}"

    reader = PdfReader(input_path)
    writer = PdfWriter()

    for i, page in enumerate(reader.pages):
        mediabox = page.mediabox
        crop = odd_crop if i % 2 == 0 else even_crop
        mediabox.lower_left = (mediabox.lower_left[0] + crop["left"], mediabox.lower_left[1] + crop["bottom"])
        mediabox.upper_right = (mediabox.upper_right[0] - crop["right"], mediabox.upper_right[1] - crop["top"])
        writer.add_page(page)

    with open(output_path, "wb") as f:
        writer.write(f)

    print(f"Cropped PDF saved to {output_path}")

# Define a function to extract tables.
# Camelot saves each page as a DF (Camelot's usual output), then each DF is saved as a CSV.
# This flow allows for the hand cleaning step of data wrangling.

def extract_tables_to_csv(input_pdf, output_dir, flavor='stream', strip_text='\n'):
    """
    Extracts tables from a PDF using Camelot and saves each table as a separate CSV file.
    Creates the output directory if it does not exist.

    Parameters:
        input_pdf (str): Path to the input PDF file.
        output_dir (str): Directory to save the CSV files.
        flavor (str): Camelot extraction flavor ('stream' or 'lattice').
        strip_text (str): Characters to strip from extracted text.
    """
   
    os.makedirs(output_dir, exist_ok=True)  # Ensure the directory exists

    tables = camelot.read_pdf(input_pdf, pages='all', flavor=flavor, strip_text=strip_text)
    print(f"Found {tables.n} tables")
    for i, table in enumerate(tables):
        output_csv = f"{output_dir}\\table_{i+1}.csv"
        table.df.to_csv(output_csv, index=False)
        print(f"Saved table {i+1} to {output_csv}")

# %%
# Define your sections as a list of dictionaries
sections = [
    {
        "name": "ordnance",
        "start_page": 60,
        "end_page": 62,
        "output_pdf": "bls_1312-10_1976_ordnance.pdf",
        "odd_crop": {"left": 0, "bottom": 87, "right": 0, "top": 31},
        "even_crop": {"left": 0, "bottom": 90, "right": 0, "top": 28}
    },
    {
        "name": "blast furnaces and steel mills",
        "start_page": 134,
        "end_page": 136,
        "output_pdf": "bls_1312-10_1976_steel_mills.pdf",
        "odd_crop": {"left": 0, "bottom": 80, "right": 0, "top": 30},
        "even_crop": {"left": 0, "bottom": 82, "right": 0, "top": 28}
    },
    {
        "name": "iron and steel foundries",
        "start_page": 136,
        "end_page": 138,
        "output_pdf": "bls_1312-10_1976_steel_mills.pdf",
        "odd_crop": {"left": 0, "bottom": 80, "right": 0, "top": 30},
        "even_crop": {"left": 0, "bottom": 82, "right": 0, "top": 28}
    },
    {
        "name": "iron and steel forgings",
        "start_page": 163,
        "end_page": 165,
        "output_pdf": "bls_1312-10_1976_steel_mills.pdf",
        "odd_crop": {"left": 0, "bottom": 80, "right": 0, "top": 30},
        "even_crop": {"left": 0, "bottom": 82, "right": 0, "top": 28}
    },
    {
        "name": "motor vehicles and equipment",
        "start_page": 314,
        "end_page": 319,
        "output_pdf": "bls_1312-10_1976_steel_mills.pdf",
        "odd_crop": {"left": 0, "bottom": 80, "right": 0, "top": 30},
        "even_crop": {"left": 0, "bottom": 82, "right": 0, "top": 28}
    },
    {
        "name": "aircraft and parts",
        "start_page": 325,
        "end_page": 328,
        "output_pdf": "bls_1312-10_1976_steel_mills.pdf",
        "odd_crop": {"left": 0, "bottom": 80, "right": 0, "top": 30},
        "even_crop": {"left": 0, "bottom": 82, "right": 0, "top": 28}
    },
    {
        "name": "ship building and repairing",
        "start_page": 338,
        "end_page": 340,
        "output_pdf": "bls_1312-10_1976_steel_mills.pdf",
        "odd_crop": {"left": 0, "bottom": 80, "right": 0, "top": 30},
        "even_crop": {"left": 0, "bottom": 82, "right": 0, "top": 28}
    },
    {
        "name": "other transportation equipment",
        "start_page": 344,
        "end_page": 346,
        "output_pdf": "bls_1312-10_1976_steel_mills.pdf",
        "odd_crop": {"left": 0, "bottom": 80, "right": 0, "top": 30},
        "even_crop": {"left": 0, "bottom": 82, "right": 0, "top": 28}
    },
    # Add more sections as needed
]

source_path = r"C:\Users\alex\coding_projects\bls_data\data\source\bls_1312-10_1976.pdf"
pdf_output_dir = r"C:\Users\alex\coding_projects\bls_data\data\pdf_output"
csv_output_dir = r"C:\Users\alex\coding_projects\bls_data\data\csv_output"

for section in sections:
    # Create subdirectories for each section
    pdf_section_dir = f"{pdf_output_dir}\\{section['name']}"
    csv_section_dir = f"{csv_output_dir}\\{section['name']}"
    os.makedirs(pdf_section_dir, exist_ok=True)
    os.makedirs(csv_section_dir, exist_ok=True)

    # Step 1: Extract the section pages
    extracted_pdf_path = f"{pdf_section_dir}\\{section['output_pdf']}"
    extract_pdf(
        source_path,
        extracted_pdf_path,
        section["start_page"],
        section["end_page"]
    )

    # Step 2: Crop the pages
    cropped_pdf_filename = f"{section['name']}_cropped.pdf"
    cropped_pdf_path = f"{pdf_section_dir}\\{cropped_pdf_filename}"
    split_and_crop(
        extracted_pdf_path,
        cropped_pdf_filename,  # This will save to pdf_section_dir
        section["odd_crop"],
        section["even_crop"]
    )

    # Step 3: Extract tables to CSV
    extract_tables_to_csv(
        cropped_pdf_path,
        csv_section_dir
    )
# Out:
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\ordnance\bls_1312-10_1976_ordnance.pdf with pages 60-62
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\ordnance\ordnance_cropped.pdf
# Found 3 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\ordnance\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\ordnance\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\ordnance\table_3.csv
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\blast furnaces and steel mills\bls_1312-10_1976_steel_mills.pdf with pages 134-136
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\blast furnaces and steel mills\blast furnaces and steel mills_cropped.pdf
# Found 4 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\blast furnaces and steel mills\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\blast furnaces and steel mills\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\blast furnaces and steel mills\table_3.csv
# Saved table 4 to C:\Users\alex\coding_projects\bls_data\data\csv_output\blast furnaces and steel mills\table_4.csv
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\iron and steel foundries\bls_1312-10_1976_steel_mills.pdf with pages 136-138
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\iron and steel foundries\iron and steel foundries_cropped.pdf
# Found 4 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\iron and steel foundries\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\iron and steel foundries\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\iron and steel foundries\table_3.csv
# Saved table 4 to C:\Users\alex\coding_projects\bls_data\data\csv_output\iron and steel foundries\table_4.csv
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\iron and steel forgings\bls_1312-10_1976_steel_mills.pdf with pages 163-165
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\iron and steel forgings\iron and steel forgings_cropped.pdf
# Found 3 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\iron and steel forgings\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\iron and steel forgings\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\iron and steel forgings\table_3.csv
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\motor vehicles and equipment\bls_1312-10_1976_steel_mills.pdf with pages 314-319
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\motor vehicles and equipment\motor vehicles and equipment_cropped.pdf
# Found 9 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_3.csv
# Saved table 4 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_4.csv
# Saved table 5 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_5.csv
# Saved table 6 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_6.csv
# Saved table 7 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_7.csv
# Saved table 8 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_8.csv
# Saved table 9 to C:\Users\alex\coding_projects\bls_data\data\csv_output\motor vehicles and equipment\table_9.csv
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\aircraft and parts\bls_1312-10_1976_steel_mills.pdf with pages 325-328
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\aircraft and parts\aircraft and parts_cropped.pdf
# Found 4 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\aircraft and parts\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\aircraft and parts\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\aircraft and parts\table_3.csv
# Saved table 4 to C:\Users\alex\coding_projects\bls_data\data\csv_output\aircraft and parts\table_4.csv
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\ship building and repairing\bls_1312-10_1976_steel_mills.pdf with pages 338-340
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\ship building and repairing\ship building and repairing_cropped.pdf
# Found 4 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\ship building and repairing\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\ship building and repairing\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\ship building and repairing\table_3.csv
# Saved table 4 to C:\Users\alex\coding_projects\bls_data\data\csv_output\ship building and repairing\table_4.csv
# Saved new PDF to C:\Users\alex\coding_projects\bls_data\data\pdf_output\other transportation equipment\bls_1312-10_1976_steel_mills.pdf with pages 344-346
# Cropped PDF saved to C:\Users\alex\coding_projects\bls_data\data\pdf_output\other transportation equipment\other transportation equipment_cropped.pdf
# Found 3 tables
# Saved table 1 to C:\Users\alex\coding_projects\bls_data\data\csv_output\other transportation equipment\table_1.csv
# Saved table 2 to C:\Users\alex\coding_projects\bls_data\data\csv_output\other transportation equipment\table_2.csv
# Saved table 3 to C:\Users\alex\coding_projects\bls_data\data\csv_output\other transportation equipment\table_3.csv
